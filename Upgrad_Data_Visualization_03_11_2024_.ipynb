# %% [markdown]
# <a href="https://colab.research.google.com/github/dheerajsharma25/IITB/blob/main/Upgrad_Data_Visualization_03_11_2024_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded  = files.upload()
# Out:
#      <input type="file" id="files-924d248e-9ada-48d3-8796-20718ca7c0ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-924d248e-9ada-48d3-8796-20718ca7c0ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
df = pd.read_csv('/content/Car_sales.csv')
df
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0       Mitsubishi  3000GT                          0.110
# 1            Dodge  Viper                           0.916
# 2    Mercedes-Benz  CL500                           0.954
# 3       Oldsmobile  Cutlass                         1.112
# 4          Porsche  Carrera Coupe                   1.280
# ..             ...                ...                 ...
# 152          Honda  Accord                        230.902
# 153           Ford  Taurus                        245.815
# 154         Toyota  Camry                         247.994
# 155           Ford  Explorer                      276.747
# 156           Ford  F-Series                      540.561
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0              20.940000    Passenger              25.450          3.0
# 1              58.470000    Passenger              69.725          8.0
# ...

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    float64
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   155 non-null    float64
#  6   Engine size          156 non-null    float64
#  7   Horsepower           157 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb weight          155 non-null    float64
#  12  Fuel capacity        156 non-null    float64
#  13  Fuel efficiency      154 non-null    float64
#  14  Latest Launch        157 non-null    object
# ...

# %%
df.describe()
# Out:
#        Sales in thousands  4-year resale value  Price in thousands  \
# count          157.000000           157.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            10.045282           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            12.545000           18.017500
# 50%             29.450000            17.710000           22.799000
# 75%             67.956000            18.140000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  157.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.518297    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...
